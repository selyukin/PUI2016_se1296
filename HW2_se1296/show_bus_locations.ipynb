# %%
# Author: Sofiya Elyukin, se1296

# Python Script for Assignment 1 of HW2 for PUI2016

#import necessary libraries
from __future__ import print_function
import json
import sys
import urllib2

#set variables
MTA_KEY = '4312dfbf-aa75-4ea8-834b-f0c9f8fc4ac0'
BUS_LINE = 'B52'
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=%s&VehicleMonitoringDetailLevel=calls&LineRef=%s"%(MTA_KEY, BUS_LINE)
    
response = urllib2.urlopen(url)
data = response.read().decode("utf-8")

dataDict = json.loads(data)

print (dataDict['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0])
#BusCount = len(VehicleActivity)
#print (data[''])
#print ('Bus Line : %s' %BUS_LINE)
# Out:
# {u'VehicleActivity': [{u'RecordedAtTime': u'2016-09-19T23:06:32.886-04:00', u'MonitoredVehicleJourney': {u'OriginRef': u'MTA_307175', u'Bearing': 6.448326, u'VehicleLocation': {u'Latitude': 40.686785, u'Longitude': -73.965168}, u'SituationRef': [], u'OperatorRef': u'MTA NYCT', u'VehicleRef': u'MTA NYCT_4452', u'BlockRef': u'MTA NYCT_FP_D6-Weekday-SDon_E_FP_78600_B52-140', u'DestinationName': u'RIDGEWOOD TERM via GATES', u'DestinationRef': u'MTA_801117', u'JourneyPatternRef': u'MTA_B520040', u'MonitoredCall': {u'VisitNumber': 1, u'StopPointRef': u'MTA_307550', u'ExpectedDepartureTime': u'2016-09-19T23:06:39.738-04:00', u'StopPointName': u'GREENE AV/WASHINGTON AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2849.02, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 4.02}}, u'ExpectedArrivalTime': u'2016-09-19T23:06:39.738-04:00'}, u'LineRef': u'MTA NYCT_B52', u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2016-09-19', u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D6-Weekday-SDon-137000_B52_140'}, u'PublishedLineName': u'B52', u'Monitored': True, u'OnwardCalls': {u'OnwardCall': [{u'VisitNumber': 1, u'StopPointRef': u'MTA_307550', u'ExpectedDepartureTime': u'2016-09-19T23:06:38.738-04:00', u'StopPointName': u'GREENE AV/WASHINGTON AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2849.02, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 4.02}}, u'ExpectedArrivalTime': u'2016-09-19T23:06:38.738-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307551', u'ExpectedDepartureTime': u'2016-09-19T23:07:46.586-04:00', u'StopPointName': u'GREENE AV/GRAND AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3107.37, u'StopsFromCall': 1, u'PresentableDistance': u'1 stop away', u'DistanceFromCall': 262.38}}, u'ExpectedArrivalTime': u'2016-09-19T23:07:46.586-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307552', u'ExpectedDepartureTime': u'2016-09-19T23:08:48.967-04:00', u'StopPointName': u'GREENE AV/CLASSON AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3346.18, u'StopsFromCall': 2, u'PresentableDistance': u'2 stops away', u'DistanceFromCall': 501.19}}, u'ExpectedArrivalTime': u'2016-09-19T23:08:48.967-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307553', u'ExpectedDepartureTime': u'2016-09-19T23:09:38.567-04:00', u'StopPointName': u'FRANKLIN AV/GREENE AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3579.41, u'StopsFromCall': 3, u'PresentableDistance': u'3 stops away', u'DistanceFromCall': 734.42}}, u'ExpectedArrivalTime': u'2016-09-19T23:09:38.567-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307674', u'ExpectedDepartureTime': u'2016-09-19T23:10:41.967-04:00', u'StopPointName': u'GATES AV/FRANKLIN AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.19, u'StopsFromCall': 4, u'PresentableDistance': u'0.6 miles away', u'DistanceFromCall': 982.19}}, u'ExpectedArrivalTime': u'2016-09-19T23:10:41.967-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307675', u'ExpectedDepartureTime': u'2016-09-19T23:11:38.100-04:00', u'StopPointName': u'GATES AV/BEDFORD AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.75, u'StopsFromCall': 5, u'PresentableDistance': u'0.7 miles away', u'DistanceFromCall': 1165.75}}, u'ExpectedArrivalTime': u'2016-09-19T23:11:38.100-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307676', u'ExpectedDepartureTime': u'2016-09-19T23:12:41.900-04:00', u'StopPointName': u'GATES AV/NOSTRAND AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.75, u'StopsFromCall': 6, u'PresentableDistance': u'0.9 miles away', u'DistanceFromCall': 1429.75}}, u'ExpectedArrivalTime': u'2016-09-19T23:12:41.900-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_307677', u'ExpectedDepartureTime': u'2016-09-19T23:14:45.127-04:00', u'StopPointName': u'GATES AV/MARCY AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.26, u'StopsFromCall': 7, u'Present ...
