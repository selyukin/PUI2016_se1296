# %%
from __future__ import print_function

# %%
import numpy as pn
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.random.rand(1)
# Out:
# array([ 0.02506072])

# %%
np.random.rand(7, 20)
# Out:
# array([[ 0.82925529,  0.19066264,  0.09505407,  0.31630348,  0.38160744,
#          0.6107975 ,  0.27998577,  0.75911851,  0.8793337 ,  0.27047548,
#          0.49424229,  0.20782636,  0.40561373,  0.11013384,  0.91501171,
#          0.99961915,  0.85553277,  0.1066345 ,  0.07203928,  0.38221289],
#        [ 0.55542402,  0.56645033,  0.23631666,  0.54709394,  0.42989696,
#          0.25709088,  0.26993452,  0.11460055,  0.2189596 ,  0.3657484 ,
#          0.15006924,  0.73237453,  0.38693549,  0.28473874,  0.00416098,
#          0.04794768,  0.21978387,  0.83464365,  0.93238658,  0.50466861],
#        [ 0.4597936 ,  0.76432281,  0.47649857,  0.92871912,  0.8026605 ,
#          0.3000546 ,  0.4823073 ,  0.14045741,  0.98951574,  0.44629284,
#          0.2627632 ,  0.44295327,  0.16152726,  0.46915393,  0.91179301,
#          0.67231064,  0.84863299,  0.55099033,  0.52319914,  0.82507961],
#        [ 0.13028037,  0.03232454,  0.1564298 ,  0.87625633,  0.8049343 ,
# ...

# %%
np.random.seed(6666666)

# %%
np.random.randn(3,2)
# Out:
# array([[-0.20761921, -0.08976755],
#        [ 1.67152011, -0.47218177],
#        [-0.68008242, -1.25781821]])

# %%
uniform_array = np.random.rand(10000)

# %%
gaussian_array = np.random.randn(10000)

# %%
pl.hist(uniform_array)
# Out:
# (array([ 1012.,   958.,  1066.,   988.,   967.,   975.,  1012.,  1011.,
#          1025.,   986.]),
#  array([  3.46023347e-05,   1.00027018e-01,   2.00019433e-01,
#           3.00011849e-01,   4.00004264e-01,   4.99996679e-01,
#           5.99989095e-01,   6.99981510e-01,   7.99973926e-01,
#           8.99966341e-01,   9.99958757e-01]),
#  <a list of 10 Patch objects>)

# %%
pl.hist (gaussian_array)
# Out:
# (array([  2.40000000e+01,   1.89000000e+02,   9.10000000e+02,
#           2.30300000e+03,   3.05400000e+03,   2.31400000e+03,
#           9.66000000e+02,   2.06000000e+02,   3.10000000e+01,
#           3.00000000e+00]),
#  array([-3.61026644, -2.81399111, -2.01771578, -1.22144045, -0.42516512,
#          0.37111021,  1.16738555,  1.96366088,  2.75993621,  3.55621154,
#          4.35248687]),
#  <a list of 10 Patch objects>)

# %%
pl.plot(uniform_array, '.')

# %%
pl.figure(figsize = (10,10))
pl.plot(gaussian_array[0], gaussian_array[1], '.')
pl.ylim(-5, 5)
pl.xlim(-5, 5)
# Out:
# (-5, 5)
